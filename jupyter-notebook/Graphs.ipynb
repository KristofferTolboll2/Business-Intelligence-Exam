# %%
import matplotlib.pyplot as plt
import random
import numpy as np

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")

num_bars = 15
x_pos = random.sample(range(20), num_bars)
y_pos = random.sample(range(20), num_bars)
z_pos = [10] * num_bars
x_size = np.ones(num_bars)
y_size = np.ones(num_bars)
z_size = random.sample(range(20), num_bars)
print(random.sample(range(20), 2))
ax.bar3d(x_pos, y_pos, z_pos, x_size, y_size, z_size, color='aqua')
plt.show()
# Out:
# [13, 8]

# %%
from dataclasses import dataclass

@dataclass(order=True)
class User:
    """Generated class for users"""
    _id: int
    mental_health_level: int
    membership_days: int = 0
    income_in_usd: int = 50000

# %%
users = []

def generate_user_data(user_amount = 1000):
    values = range(0, 100, 10)
    income_in_usd = range(30, 150, 10)
    print(list(income_in_usd))
    for userId in range(user_amount):
        user = User(userId, random.choice(values), random.choice(values), random.choice(income_in_usd))
        print(user)
        users.append(user)
        
def clear_users(users):
    users = []

# %%
generate_user_data(100)
# Out:
# [30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140]
# User(_id=0, mental_health_level=50, membership_days=40, income_in_usd=90)
# User(_id=1, mental_health_level=90, membership_days=0, income_in_usd=60)
# User(_id=2, mental_health_level=40, membership_days=50, income_in_usd=130)
# User(_id=3, mental_health_level=80, membership_days=90, income_in_usd=90)
# User(_id=4, mental_health_level=60, membership_days=0, income_in_usd=110)
# User(_id=5, mental_health_level=50, membership_days=20, income_in_usd=140)
# User(_id=6, mental_health_level=30, membership_days=20, income_in_usd=40)
# User(_id=7, mental_health_level=20, membership_days=20, income_in_usd=140)
# User(_id=8, mental_health_level=0, membership_days=50, income_in_usd=50)
# User(_id=9, mental_health_level=40, membership_days=70, income_in_usd=40)
# User(_id=10, mental_health_level=50, membership_days=10, income_in_usd=100)
# User(_id=11, mental_health_level=0, membership_days=90, income_in_usd=70)
# ...

# %%
users[:5]
# Out:
# [User(_id=0, mental_health_level=40, membership_days=80, income_in_usd=140),
#  User(_id=1, mental_health_level=50, membership_days=70, income_in_usd=40),
#  User(_id=2, mental_health_level=90, membership_days=10, income_in_usd=60),
#  User(_id=3, mental_health_level=10, membership_days=0, income_in_usd=60),
#  User(_id=4, mental_health_level=0, membership_days=20, income_in_usd=80)]

# %%
clear_users(users)

# %%
def generate_graph(users, user: User, color='aqua'):
    fig = plt.figure()
    ax = plt.axes(projection="3d")
    
    
    
    x_vals = list(map(lambda user: user.membership_days, users))
    y_vals = list(map(lambda user: user.mental_health_level, users))
    z_vals = list(map(lambda user: user.income_in_usd, users))
    
    x_vals.sort()
    y_vals.sort()
    z_vals.sort()
    
    
    num_bars = len(users)
    x_pos = x_vals
    y_pos = y_vals
    z_pos = z_vals
    x_size = np.ones(num_bars)
    y_size = np.ones(num_bars)
    z_size = random.sample(range(num_bars), num_bars)

    ax.bar3d(clear_users()x_pos, y_pos, z_pos, x_size, y_size, z_size, color=color)
    ax.bar3d(user.membership_days, user.mental_health_level, user.income_in_usd, x_size, y_size, z_size, color='aqua')
    
    plt.show()

# %%
users
# Out:
# []

# %%
random_user = random.choice(users)
print(random_user)
generate_graph(users, user=random_user, color='orange')
# Out:
# User(_id=46, mental_health_level=10, membership_days=90, income_in_usd=40)

# %%
plt.show()

# %%
generate_graph(users, color='orange')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-23edae8b9ae3> in <module>
# ----> 1 generate_graph(users, color='orange')
#
# TypeError: generate_graph() missing 1 required positional argument: 'user'
